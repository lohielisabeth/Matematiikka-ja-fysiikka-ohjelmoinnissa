# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Raw Data.csv")
df.head()
# Out:
#    Time (s)  Linear Acceleration x (m/s^2)  Linear Acceleration y (m/s^2)  \
# 0  0.000660                      -0.942669                       0.434028
# 1  0.010629                      -1.284103                       0.292341
# 2  0.020598                      -1.471747                       0.340554
# 3  0.030567                      -1.705838                       0.374397
# 4  0.040537                      -1.911015                       0.443731
#
#    Linear Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# 0                      -0.230404                       1.063058
# 1                      -0.684496                       1.484223
# 2                      -1.236643                       1.952256
# 3                      -1.770002                       2.486556
# 4                      -2.058137                       2.843379

# %%
import matplotlib.pyplot as plt

#Kuvaaja

plt.plot(df['Time (s)'], df['Linear Acceleration x (m/s^2)'])
plt.plot(df['Time (s)'], df['Linear Acceleration y (m/s^2)'])
plt.plot(df['Time (s)'], df['Linear Acceleration z (m/s^2)'])
plt.show()
